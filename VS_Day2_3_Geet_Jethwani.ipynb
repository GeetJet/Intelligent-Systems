# %% [markdown]
# <a href="https://colab.research.google.com/github/GeetJet/Vision-Systems/blob/master/VS_Day2_3_Geet_Jethwani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **i. Mount google drive**
# ---

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## **ii. Import the libraries**
# ---

# %%
import cv2
import sys
import os
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

print("Versions of key libraries")
print("---")
print("cv2:       ", cv2.__version__)
print("numpy:     ", np.__version__)
print("matplotlib:", matplotlib.__version__)
# Out:
# Versions of key libraries
# ---
# cv2:        4.1.2
# numpy:      1.18.5
# matplotlib: 3.2.2

# %% [markdown]
# ## **iii. Append /workshop in your python path**
# ---

# %%
sys.path.append('/content/gdrive/My Drive/workshop')
print("All the system paths:")
sys.path
# Out:
# All the system paths:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/gdrive/My Drive/workshop']

# %% [markdown]
# ## **iv. Change working directory to /workshop**
# ---

# %%
os.chdir('/content/gdrive/My Drive/workshop')
print("Current working directory:")
os.getcwd()
# Out:
# Current working directory:
# '/content/gdrive/My Drive/workshop'

# %% [markdown]
# ## **Question a**
# ---
# Read in the image `logos.jpg` and display the image. Name the image array as `logos`.

# %%
# Type your code below
logos = cv2.imread('logos.jpg')
cv2_imshow(logos)
# Out:
# <PIL.Image.Image image mode=RGB size=512x384 at 0x7FB4E5D45A20>

# %% [markdown]
# ## **Question b**
# ---
# Convert the image to grayscale and display the output. Name the output as `logos_gray`.

# %%
# Type your code below

logos_gray = cv2.cvtColor(logos,cv2.COLOR_BGR2GRAY)
cv2_imshow(logos_gray)
# Out:
# <PIL.Image.Image image mode=L size=512x384 at 0x7FB4DBC64588>

# %% [markdown]
# ## **Question c**
# ---
# Perform canny edge detction on `logos_gary` and display the output. Name the output as `logos_canny`

# %%
# Type your code below

logos_canny = cv2.Canny(logos_gray,51,147,apertureSize=3)
cv2_imshow(logos_canny)
# Out:
# <PIL.Image.Image image mode=L size=512x384 at 0x7FB4DA2EFD68>

# %% [markdown]
# ## **Question d**
# ___
# Create the below. Name the final output as `roi`. The colour of the boundaries is (0,255,0). Run the code below to see the required output.

# %%
cv2_imshow(cv2.imread('logos_roi.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=512x384 at 0x7FB4DBC649E8>

# %%
# Type your code below
(_,threshold)= cv2.threshold(logos_gray,250,255,cv2.THRESH_BINARY_INV)
logos_shape_iso = cv2.bitwise_and(logos,logos,mask=np.uint8(threshold))
contours,hierarchy = cv2.findContours(threshold,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(logos_shape_iso,contours,-1,(0,255,0),3)
cv2_imshow(logos_shape_iso)
# Out:
# <PIL.Image.Image image mode=RGB size=512x384 at 0x7FB4DA3027F0>
